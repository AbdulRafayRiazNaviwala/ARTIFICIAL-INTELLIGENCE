# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4,5]
y=[1,4,9,16,25]
plt.plot(x,y,'mo--',linewidth=2,markersize=12)

# %%
def create_random_walk():
    x=np.random.choice()

# %%
import numpy as np
y=np.arange(1,3)
plt.plot(y,'y');
plt.plot(y+1,'m');
plt.plot(y+2,'c');
plt.show()
